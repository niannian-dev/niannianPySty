# %% [markdown]
# # DataFrame的基础用法

# %%
import pandas as pd
import numpy as np

# %%
# DataFrame创建
s1 = pd.Series([1,2,3,4,2,1])
s2 = pd.Series([5,6,7,8,9,10])
df = pd.DataFrame({'a':s1,'b':s2})

print(df)
# Out:
#    a   b
# 0  1   5
# 1  2   6
# 2  3   7
# 3  4   8
# 4  2   9
# 5  1  10
