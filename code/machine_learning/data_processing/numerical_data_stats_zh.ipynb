# %%
#@title Copyright 2023 Google LLC. Double-click for license information.
# Licensed under the Apache License, Version 2.0 (the "License");
# you may not use this file except in compliance with the License.
# You may obtain a copy of the License at
#
# https://www.apache.org/licenses/LICENSE-2.0
#
# Unless required by applicable law or agreed to in writing, software
# distributed under the License is distributed on an "AS IS" BASIS,
# WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# See the License for the specific language governing permissions and
# limitations under the License.

# %% [markdown]
# # Colab 简介
#
# 机器学习速成课程使用 Colaboratory（Colab）完成所有编程练习。Colab 是 Google 对 [Jupyter Notebook](https://jupyter.org/) 的实现。有关 Colab 以及如何使用它的更多信息，请参阅 [Welcome to Colaboratory](https://research.google.com/colaboratory)。
#
# # 数值数据：数据集统计信息
#
# 这个 Colab 编程练习（两个练习中的第一个）属于机器学习速成课程的[处理数值数据](https://developers.google.com/machine-learning/crash-course/numerical-data)模块。

# %% [markdown]
# ## 你将学习什么
#
# 在[数值数据入门](https://developers.google.com/machine-learning/crash-course/numerical-data/first-steps)部分中，你已经学习了如何：
# - 用图表可视化数据。
# - 用数学方法评估潜在特征和标签。
# - 在数据集中发现[**离群值**](https://developers.google.com/machine-learning/glossary/#outliers)。
#
# 本练习会带你完成查找包含明显离群值的列的过程。找到之后，你可以决定保留这些数据，或者从数据集中删除它们。

# %%
# @title 环境设置 - 安装相关模块

# !pip install pandas~=2.2.0

# %%
# @title 环境设置 - 导入相关模块

# 以下代码导入相关模块，
# 使你能够运行这个 Colab。
# 如果运行后续某些代码单元时遇到技术问题，
# 可以尝试重新运行此单元。

import pandas as pd

# 以下代码调整显示结果的粒度。
pd.options.display.max_rows = 10
pd.options.display.float_format = "{:.1f}".format

# %%
#@title 导入数据集

# 以下代码导入本 Colab 使用的数据集。

training_df = pd.read_csv(filepath_or_buffer="https://download.mlcc.google.com/mledu-datasets/california_housing_train.csv")

# %% [markdown]
# ## 获取基础统计信息
#
# 在下面的代码单元中，DataFrame 的 `describe` 方法会返回数据集中所有列的基础统计信息，例如：
#
# * `count` 是这一列中有值的元素数量。理想情况下，每一列的 `count` 都相同，但现实中并不总是如此。
# * `mean` 是这一列数值的传统平均值。建议将每列的 `mean` 与中位数比较。**中位数**是表格中 `50%` 这一行。
# * `std` 是这一列数值的标准差。
# * `min`、`25%`、`50%`、`75%` 和 `max` 分别表示第 0、25、50、75 和 100 百分位的值。

# %%
# 获取数据集统计信息。

# 以下代码返回 dataframe 中数据的基础统计信息。

training_df.describe()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# count    17000.0   17000.0             17000.0      17000.0         17000.0
# mean      -119.6      35.6                28.6       2643.7           539.4
# std          2.0       2.1                12.6       2179.9           421.5
# min       -124.3      32.5                 1.0          2.0             1.0
# 25%       -121.8      33.9                18.0       1462.0           297.0
# 50%       -118.5      34.2                29.0       2127.0           434.0
# 75%       -118.0      37.7                37.0       3151.2           648.2
# max       -114.3      42.0                52.0      37937.0          6445.0
#
#        population  households  median_income  median_house_value
# count     17000.0     17000.0        17000.0             17000.0
# mean       1429.6       501.2            3.9            207300.9
# std        1147.9       384.5            1.9            115983.8
# ...

# %% [markdown]
# ### 任务：识别可能的离群值
#
# 根据前面的统计信息，你是否看到某些列可能包含离群值？

# %%
# @title 答案（运行此代码块查看） { display-mode: "form" }

print("""以下列可能包含离群值：

  * total_rooms
  * total_bedrooms
  * population
  * households
  * 可能还包括 median_income

在这些列中：

  * 标准差几乎和均值一样高
  * 75% 与 max 之间的差值远大于
      min 与 25% 之间的差值。""")
# Out:
# 以下列可能包含离群值：
#
#   * total_rooms
#   * total_bedrooms
#   * population
#   * households
#   * 可能还包括 median_income
#
# 在这些列中：
#
#   * 标准差几乎和均值一样高
#   * 75% 与 max 之间的差值远大于
#       min 与 25% 之间的差值。
